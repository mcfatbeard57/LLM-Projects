# %% [markdown]
# # Setup Environment

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Match Data >> DC vs MI

# %%
r = requests.get('https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/delhi-capitals-vs-mumbai-indians-43rd-match-1426281/full-scorecard')

# r.url

soup = BeautifulSoup(r.text, 'html.parser')
# soup.title.string

soup

# %%
#@title Pull Match 1 Batting
# Batting Data
# Innings 1

batting_columns = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[:1]:
    # print(i.text)
    # columns.append(i.text.strip())
    for j in i.find_all('th'):
        # print(j.text)
        batting_columns.append(j.text)


batting = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[:1]:
    # print(i.text)
    rows = i.find_all('td', class_='ds-min-w-max')
    for i in range(0, len(rows), 8):
        # print(i)
        batter = []
        for j in range(i, i+8):
            try:
                batter.append(rows[j].text)
            except IndexError:
                break
        # print(batter)
        batting.append(batter)


m1_innings1_batting = pd.DataFrame(batting, columns=batting_columns)

# Innings 2

batting_columns = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[1:2]:
    # print(i.text)
    # columns.append(i.text.strip())
    for j in i.find_all('th'):
        # print(j.text)
        batting_columns.append(j.text)


batting = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[1:2]:
    # print(i.text)
    rows = i.find_all('td', class_='ds-min-w-max')
    for i in range(0, len(rows), 8):
        # print(i)
        batter = []
        for j in range(i, i+8):
            try:
                batter.append(rows[j].text)
            except IndexError:
                break
        # print(batter)
        batting.append(batter)


m1_innings2_batting = pd.DataFrame(batting, columns=batting_columns)

# %%
m1_innings1_batting

# %%
m1_innings2_batting

# %%
#@title Pull Match 1 Bowling
bowling_columns = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[:1]:
    # print(i.text)
    # columns.append(i.text.strip())
    for j in i.find_all('th'):
        # print(j.text)
        bowling_columns.append(j.text)

bowling = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[:1]:
    # print(i.text)
    rows = i.find_all('td')
    bowler = []
    for i in range(0, len(rows)):
        # print(i)
        if len(bowler) < 11:
            # print(len(bowler))
            # print(rows[i].text)
            if len(rows[i].text) < 20:
                try:
                    bowler.append(rows[i].text)
                    # print(bowler)
                except IndexError:
                    break
        else:
            bowling.append(bowler)
            bowler = []
            if len(rows[i].text) < 20:
                bowler.append(rows[i].text)

m1_innings1_bowling = pd.DataFrame(bowling, columns=bowling_columns)




bowling_columns = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[1:2]:
    # print(i.text)
    # columns.append(i.text.strip())
    for j in i.find_all('th'):
        # print(j.text)
        bowling_columns.append(j.text)

bowling = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[1:2]:
    # print(i.text)
    rows = i.find_all('td')
    bowler = []
    for i in range(0, len(rows)):
        # print(i)
        if len(bowler) < 11:
            # print(len(bowler))
            # print(rows[i].text)
            if len(rows[i].text) < 20:
                try:
                    bowler.append(rows[i].text)
                    # print(bowler)
                except IndexError:
                    break
        else:
            bowling.append(bowler)
            bowler = []
            if len(rows[i].text) < 20:
                bowler.append(rows[i].text)

m1_innings2_bowling = pd.DataFrame(bowling, columns=bowling_columns)

# %%
m1_innings1_bowling

# %%
m1_innings2_bowling

# %% [markdown]
# # Match Data >> LSG vs RR

# %%
r = requests.get('https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/lucknow-super-giants-vs-rajasthan-royals-44th-match-1426282/full-scorecard')

# r.url

soup = BeautifulSoup(r.text, 'html.parser')
# soup.title.string

soup

# %%
#@title Pull Match 2 Batting
# Batting Data
# Innings 1

batting_columns = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[:1]:
    # print(i.text)
    # columns.append(i.text.strip())
    for j in i.find_all('th'):
        # print(j.text)
        batting_columns.append(j.text)


batting = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[:1]:
    # print(i.text)
    rows = i.find_all('td', class_='ds-min-w-max')
    for i in range(0, len(rows), 8):
        # print(i)
        batter = []
        for j in range(i, i+8):
            try:
                batter.append(rows[j].text)
            except IndexError:
                break
        # print(batter)
        batting.append(batter)


m2_innings1_batting = pd.DataFrame(batting, columns=batting_columns)

# Innings 2

batting_columns = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[1:2]:
    # print(i.text)
    # columns.append(i.text.strip())
    for j in i.find_all('th'):
        # print(j.text)
        batting_columns.append(j.text)


batting = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[1:2]:
    # print(i.text)
    rows = i.find_all('td', class_='ds-min-w-max')
    for i in range(0, len(rows), 8):
        # print(i)
        batter = []
        for j in range(i, i+8):
            try:
                batter.append(rows[j].text)
            except IndexError:
                break
        # print(batter)
        batting.append(batter)


m2_innings2_batting = pd.DataFrame(batting, columns=batting_columns)

# %%
m2_innings1_batting

# %%
m2_innings2_batting

# %%
#@title Pull Match 2 Bowling
bowling_columns = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[:1]:
    # print(i.text)
    # columns.append(i.text.strip())
    for j in i.find_all('th'):
        # print(j.text)
        bowling_columns.append(j.text)

bowling = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[:1]:
    # print(i.text)
    rows = i.find_all('td')
    bowler = []
    for i in range(0, len(rows)):
        # print(i)
        if len(bowler) < 11:
            # print(len(bowler))
            # print(rows[i].text)
            if len(rows[i].text) < 20:
                try:
                    bowler.append(rows[i].text)
                    # print(bowler)
                except IndexError:
                    break
        else:
            bowling.append(bowler)
            bowler = []
            if len(rows[i].text) < 20:
                bowler.append(rows[i].text)

m2_innings1_bowling = pd.DataFrame(bowling, columns=bowling_columns)




bowling_columns = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[1:2]:
    # print(i.text)
    # columns.append(i.text.strip())
    for j in i.find_all('th'):
        # print(j.text)
        bowling_columns.append(j.text)

bowling = []

for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[1:2]:
    # print(i.text)
    rows = i.find_all('td')
    bowler = []
    for i in range(0, len(rows)):
        # print(i)
        if len(bowler) < 11:
            # print(len(bowler))
            # print(rows[i].text)
            if len(rows[i].text) < 20:
                try:
                    bowler.append(rows[i].text)
                    # print(bowler)
                except IndexError:
                    break
        else:
            bowling.append(bowler)
            bowler = []
            if len(rows[i].text) < 20:
                bowler.append(rows[i].text)

m2_innings2_bowling = pd.DataFrame(bowling, columns=bowling_columns)

# %%
m2_innings1_bowling

# %%
m2_innings2_bowling

# %% [markdown]
# # Fantasy Team X GPT

# %%
# !pip install openai==1.12.0

# %%
from openai import OpenAI
from google.colab import userdata
client = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))

def get_completion(m1_link, ):
  system_prompt = f"""
  You are a huge cricket fan, and good with analysing match data.
  """

  prompt = f"""
  I will provide you batting & bowling data for two cricket matches.
  Match 1 data provided between three backticks.
  Match 2 data provided between separator ####.
  Now, one team from each of these two matches are playing tonight.
  Your task is to analyse the two matches data.
  And create a Fantasy team for tonight's match between MI & LSG.
  This fantasy team should have 11 players.

  ```
  Match 1: MI vs DC
  Innings 1 >> DC Batting
  {m1_innings1_batting}
  Innings 1 >> MI Bowling
  {m1_innings1_bowling}
  Innings 2 >> MI Batting
  {m1_innings2_batting}
  Innings 2 >> DC Bowling
  {m1_innings2_bowling}
  ```

  ####
  Match 1: LSG vs RR
  Innings 1 >> LSG Batting
  {m1_innings1_batting}
  Innings 1 >> RR Bowling
  {m1_innings1_bowling}
  Innings 2 >> RR Batting
  {m1_innings2_batting}
  Innings 2 >> LSG Bowling
  {m1_innings2_bowling}
  ####

  """

  messages=[
      {"role": "system", "content": system_prompt},
      {"role": "user", "content": prompt}
      ]

  print(messages)             # for testing

  response = client.chat.completions.create(
                            model="gpt-4-turbo-2024-04-09",
                            messages=messages,
                            temperature=0
                            )
  response.choices[0].message.content

# %%
print(response.choices[0].message.content)

# %% [markdown]
# # Gradio App

# %%
# !pip install openai==1.12.0
# Out:
# Collecting openai==1.12.0
#   Downloading openai-1.12.0-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.12.0) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai==1.12.0) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai==1.12.0)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai==1.12.0) (2.7.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai==1.12.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai==1.12.0) (4.66.2)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai==1.12.0) (4.11.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai==1.12.0) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai==1.12.0) (1.2.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai==1.12.0) (2024.2.2)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai==1.12.0)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.8 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.12.0)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.12.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai==1.12.0) (2.18.2)
# Installing collected packages: h11, httpcore, httpx, openai
# Successfully installed h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 openai-1.12.0

# %%
# !pip install gradio==4.19.0
# Out:
# Collecting gradio==4.19.0
#   Downloading gradio-4.19.0-py3-none-any.whl (16.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 65.6 MB/s eta 0:00:00
# Collecting aiofiles<24.0,>=22.0 (from gradio==4.19.0)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (4.2.2)
# Collecting fastapi (from gradio==4.19.0)
#   Downloading fastapi-0.110.3-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 13.4 MB/s eta 0:00:00
# Collecting ffmpy (from gradio==4.19.0)
#   Downloading ffmpy-0.3.2.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Collecting gradio-client==0.10.0 (from gradio==4.19.0)
#   Downloading gradio_client-0.10.0-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 27.1 MB/s eta 0:00:00
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (0.27.0)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (0.20.3)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (6.4.0)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (3.1.3)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (3.7.1)
# Requirement already satisfied: numpy~=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (1.25.2)
# Collecting orjson~=3.0 (from gradio==4.19.0)
#   Downloading orjson-3.10.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.7/142.7 kB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (24.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (2.0.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (9.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (2.7.1)
# Collecting pydub (from gradio==4.19.0)
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting python-multipart (from gradio==4.19.0)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (6.0.1)
# Collecting ruff>=0.1.7 (from gradio==4.19.0)
#   Downloading ruff-0.4.2-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 99.4 MB/s eta 0:00:00
# Collecting semantic-version~=2.0 (from gradio==4.19.0)
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting tomlkit==0.12.0 (from gradio==4.19.0)
#   Downloading tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (0.9.4)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio==4.19.0) (4.11.0)
# Collecting uvicorn>=0.14.0 (from gradio==4.19.0)
#   Downloading uvicorn-0.29.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.10.0->gradio==4.19.0) (2023.6.0)
# Collecting websockets<12.0,>=10.0 (from gradio-client==0.10.0->gradio==4.19.0)
#   Downloading websockets-11.0.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.19.0) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.19.0) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6.0,>=4.2.0->gradio==4.19.0) (0.12.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.19.0) (3.13.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.19.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.3->gradio==4.19.0) (4.66.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.19.0) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.19.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.19.0) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.19.0) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.19.0) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib~=3.0->gradio==4.19.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.19.0) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio==4.19.0) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.19.0) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio==4.19.0) (2.18.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio==4.19.0) (8.1.7)
# Collecting colorama<0.5.0,>=0.4.3 (from typer[all]<1.0,>=0.9->gradio==4.19.0)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting shellingham<2.0.0,>=1.3.0 (from typer[all]<1.0,>=0.9->gradio==4.19.0)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer[all]<1.0,>=0.9->gradio==4.19.0) (13.7.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn>=0.14.0->gradio==4.19.0) (0.14.0)
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi->gradio==4.19.0)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.19.0) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.19.0) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.19.0) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.19.0) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==4.19.0) (1.3.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.19.0) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.19.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.19.0) (0.35.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.19.0) (0.18.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.19.0) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.19.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.19.0) (2.16.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->gradio==4.19.0) (1.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->gradio==4.19.0) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.19.3->gradio==4.19.0) (2.0.7)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio==4.19.0) (0.1.2)
# Building wheels for collected packages: ffmpy
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.2-py3-none-any.whl size=5584 sha256=c9f7e31a28d9db3d5a1cd531e384d8585b436668944d8119bdf27d27a32f0a5f
#   Stored in directory: /root/.cache/pip/wheels/bd/65/9a/671fc6dcde07d4418df0c592f8df512b26d7a0029c2a23dd81
# Successfully built ffmpy
# Installing collected packages: pydub, ffmpy, websockets, uvicorn, tomlkit, shellingham, semantic-version, ruff, python-multipart, orjson, colorama, aiofiles, starlette, gradio-client, fastapi, gradio
# Successfully installed aiofiles-23.2.1 colorama-0.4.6 fastapi-0.110.3 ffmpy-0.3.2 gradio-4.19.0 gradio-client-0.10.0 orjson-3.10.2 pydub-0.25.1 python-multipart-0.0.9 ruff-0.4.2 semantic-version-2.10.0 shellingham-1.5.4 starlette-0.37.2 tomlkit-0.12.0 uvicorn-0.29.0 websockets-11.0.3

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from openai import OpenAI
import gradio as gr
from google.colab import userdata
client = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))


def pull_match_data(m_link):
  r = requests.get(m_link)
  # r.url
  soup = BeautifulSoup(r.text, 'html.parser')
  # soup.title.string

  # Batting Innings: 1
  batting_columns = []
  for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[:1]:
      # print(i.text)
      # columns.append(i.text.strip())
      for j in i.find_all('th'):
          # print(j.text)
          batting_columns.append(j.text)
  batting = []
  for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[:1]:
      # print(i.text)
      rows = i.find_all('td', class_='ds-min-w-max')
      for i in range(0, len(rows), 8):
          # print(i)
          batter = []
          for j in range(i, i+8):
              try:
                  batter.append(rows[j].text)
              except IndexError:
                  break
          # print(batter)
          batting.append(batter)
  innings1_batting = pd.DataFrame(batting, columns=batting_columns)

  # Batting Innings: 2
  batting_columns = []
  for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[1:2]:
      # print(i.text)
      # columns.append(i.text.strip())
      for j in i.find_all('th'):
          # print(j.text)
          batting_columns.append(j.text)
  batting = []
  for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto ci-scorecard-table')[1:2]:
      # print(i.text)
      rows = i.find_all('td', class_='ds-min-w-max')
      for i in range(0, len(rows), 8):
          # print(i)
          batter = []
          for j in range(i, i+8):
              try:
                  batter.append(rows[j].text)
              except IndexError:
                  break
          # print(batter)
          batting.append(batter)
  innings2_batting = pd.DataFrame(batting, columns=batting_columns)

  # Bowling Innings: 1
  bowling_columns = []
  for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[:1]:
      # print(i.text)
      # columns.append(i.text.strip())
      for j in i.find_all('th'):
          # print(j.text)
          bowling_columns.append(j.text)
  bowling = []
  for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[:1]:
      # print(i.text)
      rows = i.find_all('td')
      bowler = []
      for i in range(0, len(rows)):
          # print(i)
          if len(bowler) < 11:
              # print(len(bowler))
              # print(rows[i].text)
              if len(rows[i].text) < 20:
                  try:
                      bowler.append(rows[i].text)
                      # print(bowler)
                  except IndexError:
                      break
          else:
              bowling.append(bowler)
              bowler = []
              if len(rows[i].text) < 20:
                  bowler.append(rows[i].text)
  innings1_bowling = pd.DataFrame(bowling, columns=bowling_columns)

  # Bowling Innings: 2
  bowling_columns = []
  for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[1:2]:
      # print(i.text)
      # columns.append(i.text.strip())
      for j in i.find_all('th'):
          # print(j.text)
          bowling_columns.append(j.text)
  bowling = []
  for i in soup.find_all(class_='ds-w-full ds-table ds-table-md ds-table-auto')[1:2]:
      # print(i.text)
      rows = i.find_all('td')
      bowler = []
      for i in range(0, len(rows)):
          # print(i)
          if len(bowler) < 11:
              # print(len(bowler))
              # print(rows[i].text)
              if len(rows[i].text) < 20:
                  try:
                      bowler.append(rows[i].text)
                      # print(bowler)
                  except IndexError:
                      break
          else:
              bowling.append(bowler)
              bowler = []
              if len(rows[i].text) < 20:
                  bowler.append(rows[i].text)
  innings2_bowling = pd.DataFrame(bowling, columns=bowling_columns)

  return innings1_batting, innings1_bowling, innings2_batting,innings2_bowling


def get_completion(m1_link, m1_batting_team, m1_bowling_team,
                   m2_link, m2_batting_team, m2_bowling_team,
                   m3_team1, m3_team2,
                   model="gpt-4-turbo-2024-04-09"):

  m1_innings1_batting, m1_innings1_bowling, m1_innings2_batting, m1_innings2_bowling = pull_match_data(m1_link)
  m2_innings1_batting, m2_innings1_bowling, m2_innings2_batting, m2_innings2_bowling = pull_match_data(m2_link)

  system_prompt = f"""
  You are a huge cricket fan, and good with analysing match data.
  """

  prompt = f"""
  I will provide you batting & bowling data for two cricket matches.
  Match 1 data provided between three backticks.
  Match 2 data provided between separator ####.
  Now, one team from each of these two matches are playing tonight.
  Your task is to analyse the two matches data.
  And create a Fantasy team for tonight's match between {m3_team1} & {m3_team2}.
  This fantasy team should have 11 players.

  ```
  Match 1: {m1_batting_team} vs {m1_bowling_team}
  Innings 1 >> {m1_batting_team} Batting
  {m1_innings1_batting}
  Innings 1 >> {m1_bowling_team} Bowling
  {m1_innings1_bowling}
  Innings 2 >> {m1_bowling_team} Batting
  {m1_innings2_batting}
  Innings 2 >> {m1_batting_team} Bowling
  {m1_innings2_bowling}
  ```

  ####
  Match 1: {m2_batting_team} vs {m2_bowling_team}
  Innings 1 >> {m2_batting_team} Batting
  {m2_innings1_batting}
  Innings 1 >> {m2_bowling_team} Bowling
  {m1_innings1_bowling}
  Innings 2 >> {m2_bowling_team} Batting
  {m2_innings2_batting}
  Innings 2 >> {m2_batting_team} Bowling
  {m2_innings2_bowling}
  ####

  """

  messages=[
      {"role": "system", "content": system_prompt},
      {"role": "user", "content": prompt}
      ]

  # print(messages)             # for testing
  response = client.chat.completions.create(
                            model="gpt-4-turbo-2024-04-09",
                            messages=messages,
                            temperature=0
                            )
  return response.choices[0].message.content


iface = gr.Interface(fn=get_completion,
                     inputs=[gr.Textbox(label="Team 1 Last Match Scorecard",lines=1,info="Check here: https://www.espncricinfo.com/"),
                             gr.Dropdown(
                                ["","CSK","DC","GT","KKR","LSG","MI","PK","RR","RCB","SRH"], label="Team Batting First"),
                             gr.Dropdown(
                                ["","CSK","DC","GT","KKR","LSG","MI","PK","RR","RCB","SRH"], label="Team Bowling"),

                             gr.Textbox(label="Team 2 Last Match Scorecard",lines=1,info="Check here: https://www.espncricinfo.com/"),
                             gr.Dropdown(
                                ["","CSK","DC","GT","KKR","LSG","MI","PK","RR","RCB","SRH"], label="Team Batting First"),
                             gr.Dropdown(
                                ["","CSK","DC","GT","KKR","LSG","MI","PK","RR","RCB","SRH"], label="Team Bowling"),

                             gr.Dropdown(
                                ["","CSK","DC","GT","KKR","LSG","MI","PK","RR","RCB","SRH"], label="Teams Playing Today"),
                             gr.Dropdown(
                                ["","CSK","DC","GT","KKR","LSG","MI","PK","RR","RCB","SRH"], label=""),

                             gr.Dropdown(
                                ["","gpt-3.5-turbo-1106","gpt-4-1106-preview","gpt-4-turbo-2024-04-09"], label="GPT Model API",
                                info="Choose 'gpt-3.5-turbo-1106', if unsure"),
                             ],
                     outputs=[gr.Textbox(label="Your Fantasy XI",lines=9)],
                     title="Fantasy XI using AI",
                     description="Generate your Dream XI, MPL Fantasy Team using AI")
iface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://5273f224650dc3b43b.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5273f224650dc3b43b.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/chennai-super-kings-vs-sunrisers-hyderabad-46th-match-1426284/full-scorecard
# CSK
# SRH
# https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/kolkata-knight-riders-vs-punjab-kings-42nd-match-1426280/full-scorecard
# KKR
# PK

# CSK
# PK
